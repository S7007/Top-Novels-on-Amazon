# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("AmazonBooks - Sheet1.csv")
df.head(4)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
# 3                   1984 (Signet Classics)       George Orwell          4.7
#
#    Reviews  Price  Year        Genre
# 0    17350      8  2016  Non Fiction
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction
# 3    21424      6  2017      Fiction

# %%
df.tail(5)
# Out:
#                                                   Name           Author  \
# 595  Live Free Or Die: America (and the World) on t...     Sean Hannity
# 596                                 Burn After Writing     Sharon Jones
# 597  Get Out of Your Head: Stopping the Spiral of T...     Jennie Allen
# 598  Human Body Activity Book for Kids: Hands-On Fu...     Katie Stokes
# 599                                 Educated: A Memoir   Tara Westover
#
#      User Rating  Reviews  Price  Year        Genre
# 595          4.8    20153     15  2020  Non Fiction
# 596          4.6    26423      8  2020  Non Fiction
# 597          4.7    12879     14  2020  Non Fiction
# 598          4.7    14128      5  2020  Non Fiction
# 599          4.7    45351     11  2020  Non Fiction

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         600 non-null    object
#  1   Author       600 non-null    object
#  2   User Rating  600 non-null    float64
#  3   Reviews      600 non-null    int64
#  4   Price        600 non-null    int64
#  5   Year         600 non-null    int64
#  6   Genre        600 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 32.9+ KB

# %%
df.describe()
# Out:
#        User Rating        Reviews      Price         Year
# count   600.000000     600.000000  600.00000   600.000000
# mean      4.627333   13941.730000   12.92000  2014.500000
# std       0.225324   14652.813591   10.49717     3.454933
# min       3.300000      37.000000    0.00000  2009.000000
# 25%       4.500000    4586.500000    7.00000  2011.750000
# 50%       4.700000    9059.500000   11.00000  2014.500000
# 75%       4.800000   19587.500000   16.00000  2017.250000
# max       4.900000  120727.000000  105.00000  2020.000000

# %%
df.isnull().sum()
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %%
plt.figure(figsize=(15, 5))
sns.set_theme(style="darkgrid")
sns.countplot(x='Genre', data=df)
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.histplot(x=df['User Rating'], kde=True, fill=True)
plt.title("User Rating distribution")
plt.show()

# %%
g = sns.displot(x=df['User Rating'], hue=df['Genre'], kind="kde", fill=True)
plt.title("User Rating distribution by Genre")
g.fig.set_figwidth(15)
g.fig.set_figheight(5)
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.boxenplot(x="Year", y="User Rating", data=df)
plt.title('User rating distribution by year')
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.histplot(x="Price", data=df, fill="True", kde=True)
plt.title("Price distribution")
plt.show()

# %%
g = sns.displot(x=df['Price'], hue=df['Genre'], kind="kde", fill=True)
plt.title("Price distribution by Genre")
g.fig.set_figwidth(15)
g.fig.set_figheight(5)
plt.show()

# %%
df.query('Price > 75')
# Out:
#                                                   Name  \
# 69   Diagnostic and Statistical Manual of Mental Di...
# 70   Diagnostic and Statistical Manual of Mental Di...
# 473                       The Twilight Saga Collection
#
#                                Author  User Rating  Reviews  Price  Year  \
# 69   American Psychiatric Association          4.5     6679    105  2013
# 70   American Psychiatric Association          4.5     6679    105  2014
# 473                   Stephenie Meyer          4.7     3801     82  2009
#
#            Genre
# 69   Non Fiction
# 70   Non Fiction
# 473      Fiction

# %%
plt.figure(figsize=(15, 5))
sns.pointplot(x="Year", y="Price", hue="Genre", data=df, alpha=.3)
plt.title('Price distribution by year and genre')
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.histplot(x="Reviews", data=df, fill="True", kde=True)
plt.title("Reviews distribution")
plt.show()

# %%
df.query("Reviews > 90000")
# Out:
#                                                   Name                Author  \
# 551  Too Much and Never Enough: How My Family Creat...  Mary L. Trump Ph.D.
# 552                            Where the Crawdads Sing           Delia Owens
# 563                                          Becoming         Michelle Obama
#
#      User Rating  Reviews  Price  Year        Genre
# 551          4.6    94196     17  2020  Non Fiction
# 552          4.8   120727      9  2020      Fiction
# 563          4.8    99498     10  2020  Non Fiction

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

sns.scatterplot(x="Price", y="Reviews", hue='Genre', data=df, ax=ax[0])
sns.scatterplot(x="Price", y="User Rating", hue='Genre', data=df, ax=ax[1])
plt.show()
